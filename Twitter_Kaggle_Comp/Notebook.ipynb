# %%
from twitter_data import TwitterData

train_filename = 'data_files/train.csv'
test_filename = 'data_files/test.csv'

twitter_train = TwitterData(train_filename)
twitter_test = TwitterData(test_filename, test_set=True)

# %%
from sklearn.compose import ColumnTransformer

fit_transform(X, y=None)
# Out:
#          id  keyword                       location  \
# 31       48   ablaze                     Birmingham
# 32       49   ablaze  Est. September 2012 - Bristol
# 33       50   ablaze                         AFRICA
# 34       52   ablaze               Philadelphia, PA
# 35       53   ablaze                     London, UK
# ...     ...      ...                            ...
# 7575  10826  wrecked                             TN
# 7577  10829  wrecked         #NewcastleuponTyne #UK
# 7579  10831  wrecked              Vancouver, Canada
# 7580  10832  wrecked                        London
# 7581  10833  wrecked                        Lincoln
#
#                                                    text  target  doc_freq  \
# 31    @bbcmtd Wholesale Markets ablaze http://t.co/l...       1  0.057305
# 32    We always try to bring the heavy. #metal #RT h...       0  0.476700
# 33    #AFRICANBAZE: Breaking news:Nigeria flag set a...       1  0.466956
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf.fit(twitter_train.asmatrix, twitter_train.labels)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
y = clf.predict(twitter_test.asmatrix)

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
import pandas as pd

n = len(twitter_test.df)

predicted_results = pd.DataFrame(columns=['id', 'target'])
predicted_results['id'] = twitter_test.df['id']
predicted_results['target'] = y
predicted_results.set_index('id', inplace=True)

# %%
predicted_results
# Out:
#        target
# id
# 0           1
# 2           1
# 3           1
# 9           1
# 11          1
# ...       ...
# 10861       1
# 10865       1
# 10868       1
# 10874       1
# 10875       1
#
# [3263 rows x 1 columns]

# %%
predicted_results.to_csv('dk_tw_results.csv')
